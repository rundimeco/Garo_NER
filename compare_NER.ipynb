# %%
import json
import glob
import tools_compare as tc
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Recherche des entités les plus similaires au sein d'une liste classées par ordre décroissant de similarité.**
#
# Attention le temps de calcul n'est pas linéaire en la taille des données, compter moins d'une seconde pour
# 100 entités mais 15 secondes pour 500
#
# NB: exemples pris sur des exttactions réalisées par Caroline Parfait : https://github.com/These-SCAI2023/NER_GEO_COMPAR/tree/master/DATA

# %%
liste_DATA = glob.glob("DATA/*")

path = liste_DATA[0]
print(path, "\n")
start = time.time()
echantillon = 100
with open(path) as f:
  liste_aimard_kraken = json.load(f)
  NBocc = len(liste_aimard_kraken)
  NBtyp = len(set(liste_aimard_kraken))
  print(f"{NBocc} occurrences ({NBtyp} entités uniques), test sur un échantillon de {echantillon} occurrences")
  
  out = tc.get_similar_in_list(liste_aimard_kraken[:echantillon])
  end = time.time()
  print("Results computed in %f seconds : \n"%(end-start))
  for entite, closest in out.items():        
    print(entite, closest[:5])
    break
# Out:
# DATA/AIMARD_les-trappeurs_Kraken-base.txt_lg_spacy.json
#
# 976 occurrences (470 entités uniques), test sur un échantillon de 100 occurrences
# Results computed in 0.507596 seconds :
#
# l'Amerique [[0.8660254037844387, 'Amerique'], [0.375, 'Americains'], [0.375, 'Americaine'], [0.316227766016838, 'Mexique'], [0.2672612419124244, 'Pacifique']]

# %% [markdown]
# **Une entité Vs une liste**

# %%
entite_cherchee = "amerique"
seuil = 0.5
print(f"recherche des entités les plus proches de \"{entite_cherchee}\" dans {path}")
tc.get_similar_entity_VS_list(entite_cherchee, liste_aimard_kraken)
# Out:
# recherche des entités les plus proches de "amerique" dans DATA/AIMARD_les-trappeurs_Kraken-base.txt_lg_spacy.json
# {'amerique': [[1.0, 'Amerique'],
#   [0.8660254037844386, "l'Amerique"],
#   [0.7302967433402215, 'Aerique'],
#   [0.6546536707079771, 'Amerique du Nord'],
#   [0.4629100498862757, "l'Afrique"],
#   [0.4330127018922193, 'Americains'],
#   [0.4330127018922193, 'Americaine'],
#   [0.408248290463863, 'Utique'],
#   [0.408248290463863, 'Americaines'],
#   [0.3651483716701107, 'Mexique'],
#   [0.33333333333333337, 'Mlexique'],
#   [0.3086066999241839, 'Pacifique'],
#   [0.28867513459481287, 'Ame-'],
#   [0.2357022603955159, 'mereI'],
#   [0.20412414523193156, 'Quebec'],
#   [0.18257418583505536, 'serieux'],
#   [0.18257418583505536, 'Buluque'],
#   [0.16666666666666674, 'memanque'],
#   [0.16666666666666674, 'Azteques'],
#   [0.14433756729740643, 'Linterieur'],
#   [0.09622504486493766, 'couvent de la Merced'],
#   [0.09622504486493766, 'Etats Barbaresques']]}

# %% [markdown]
# **Comparaison des entités d'un texte océrisé avec une version de référence**
#
# *Attention au temps de calcul si vous augmentez la taille de l'échantillon*

# %%
path2 = liste_DATA[1]
print(f"{path2} VS \n{path}")

with open(path2) as f:
  liste_aimard_ref = json.load(f)

start = time.time()
out = tc.get_similar_two_lists(liste_aimard_ref[:200], liste_aimard_kraken[:200])
end = time.time()
print("Results computed in %f seconds : \n"%(end-start))
for entite, liste_similar in out.items():
    print(entite)
    for item in liste_similar[:10]:
        print("  ",item)
# Out:
# DATA/AIMARD_les-trappeurs_PP.txt_lg_spacy.json VS
# DATA/AIMARD_les-trappeurs_Kraken-base.txt_lg_spacy.json
# Results computed in 1.564649 seconds :
#
# l'Amérique
#    [0.625, "l'Amerique"]
#    [0.4330127018922194, 'Amerique']
#    [0.316227766016838, 'Mexique']
#    [0.2672612419124244, 'Pacifique']
#    [0.14433756729740643, 'Azteques']
# Amérique
#    [0.5, 'Amerique']
#    [0.4330127018922194, "l'Amerique"]
#    [0.3651483716701107, 'Mexique']
#    [0.30860669992418377, 'Pacifique']
#    [0.16666666666666663, 'Azteques']
# Espagnols
#    [1.0, 'Espagnols']
#    [0.5714285714285714, "d'Espagne"]
#    [0.1428571428571428, 'Ignorante']
# Incas
#    [1.0, 'Incas']
#    [0.2357022603955159, 'Francais']
# l'Europe
#    [0.8164965809277259, 'Europe']
#    [0.28867513459481287, 'Ceur']
#    [0.23570226039551578, 'Caeur']
#    [0.20412414523193145, 'meurtI']
#    [0.16666666666666663, 'Malheurl']
#    [0.15430334996209194, 'Belhumeur']
#    [0.14433756729740643, 'Ceur Loyal']
#    [0.13608276348795434, 'Caeur Loyal']
#    [0.10910894511799618, 'Votre Seigneurie']
#    [0.09128709291752768, 'Parbleul dit Belhumeur']
# États
#    [0.6666666666666667, 'Etats']
#    [0.5773502691896258, 'tat']
#    [0.40824829046386313, 'Etats-Unis']
#    [0.40824829046386313, 'Etat']
#    [0.3086066999241839, 'Etats de Durango']
# État de Sonora
#    [0.5773502691896257, 'Sonora']
#    [0.28867513459481287, 'tat']
#    [0.23145502494313785, 'Etats de Durango']
#    [0.21821789023599236, 'Le soleil']
#    [0.21821789023599236, 'Ignorante']
#    [0.20412414523193145, 'Etat']
#    [0.16666666666666663, 'golfe de Cali-']
#    [0.16666666666666663, 'Etats']
#    [0.14002800840280094, 'Cerro de la campana']
#    [0.10910894511799618, 'le desert']
# rio Gila
#    [1.0, 'Rio Gila']
#    [0.13608276348795434, 'del Milagro']
#    [0.09622504486493766, 'hacienda del Milagro']
#    [0.06454972243679025, 'calle del Rosario,- rue du Rosaire']
# État
#    [0.5773502691896257, 'tat']
#    [0.4082482904638629, 'Etat']
#    [0.33333333333333326, 'Etats']
#    [0.20412414523193145, 'Etats-Unis']
#    [0.15430334996209194, 'Etats de Durango']
# sierra Madre
#    [1.0, 'Sierra Madre']
#    [0.18257418583505536, 'terre']
#    [0.14142135623730945, 'Derrire']
#    [0.11952286093343933, 'La metise']
#    [0.07669649888473706, 'Cerro de la campana']
# golfe de Californie
#    [0.7701540462154053, 'golfe de Cali-']
#    [0.19446111706564928, 'Etats de Durango']
#    [0.1833396994056422, 'le desert']
#    [0.1833396994056422, 'Le desert']
#    [0.17647058823529416, 'Cerro de la campana']
#    [0.15339299776947413, 'calle del Rosario,- rue du Rosaire']
#    [0.12126781251816643, 'foruie']
#    [0.10846522890932808, 'forlune']
#    [0.10846522890932808, 'Pawnies']
#    [0.07669649888473706, "Tete d'Aigle"]
# Durango
#    [1.0, 'Durango']
#    [0.5976143046671968, 'Etats de Durango']
#    [0.3651483716701107, 'etranger']
#    [0.282842712474619, 'sion etrange']
#    [0.19999999999999996, 'Aransas']
#    [0.18257418583505536, 'Francais']
#    [0.16903085094570325, 'Ignorante']
#    [0.10540925533894596, 'Gambusinos demi-sang']
# États de Durango
#    [0.9285714285714286, 'Etats de Durango']
#    [0.5976143046671969, 'Durango']
#    [0.3086066999241839, 'Etats']
#    [0.2672612419124244, 'tat']
#    [0.23145502494313785, 'golfe de Cali-']
#    [0.21821789023599236, 'etranger']
#    [0.20203050891044216, 'le desert']
#    [0.20203050891044216, 'Le desert']
#    [0.18898223650461365, 'Etats-Unis']
#    [0.18898223650461365, 'Etat']
# Guadalajara
#    [0.6666666666666666, 'Guadalazara']
#    [0.2357022603955159, 'Guadeloupe']
#    [0.14907119849998596, 'Guaymas']
#    [0.14907119849998596, 'Aransas']
#    [0.13608276348795434, 'feodales']
# Pacifique
#    [1.0, 'Pacifique']
#    [0.3380617018914066, 'Mexique']
#    [0.3086066999241839, 'Amerique']
#    [0.2672612419124244, "l'Amerique"]
#    [0.15430334996209194, 'Azteques']
#    [0.08908708063747484, 'hacienda del Milagro']
# Sonora
#    [1.0, 'Sonora']
#    [0.3779644730092273, 'Ignorante']
# Indiens
#    [1.0, 'Indiens']
#    [0.8944271909999159, 'Indien']
#    [0.3651483716701107, 'Canadien']
#    [0.316227766016838, 'Canadienne']
#    [0.2581988897471611, 'Dieul']
#    [0.16903085094570325, 'Dieul Dix']
#    [0.10540925533894596, 'hacienda del Milagro']
# Comanches
#    [1.0, 'Comanches']
#    [0.5714285714285714, 'Comancles']
#    [0.15430334996209194, 'maneuvre']
#    [0.15430334996209194, 'Francais']
# Pawnees
#    [0.3999999999999999, 'Pawnies']
#    [0.22360679774997894, 'Linnee']
#    [0.19999999999999996, 'journee']
# Pimas
#    [1.0, 'Pimas']
#    [0.2581988897471611, 'Guaymas']
# Guaymas
#    [1.0, 'Guaymas']
#    [0.2581988897471611, 'Pimas']
#    [0.158113883008419, 'Guadeloupe']
#    [0.14907119849998596, 'Guadalazara']
# Hermosillo
#    [1.0, 'Hermosillo']
#    [0.17677669529663687, 'Lherbe']
#    [0.158113883008419, 'Allonsl']
#    [0.14433756729740643, 'eveillee']
#    [0.11785113019775795, 'Cordilleres']
# Arispe
#    [1.0, 'Arispe']
#    [0.0790569415042095, 'calle del Rosario,- rue du Rosaire']
# Pitic
#    [0.2581988897471611, 'Jupiter']
# el Cerro
#    [0.29704426289300234, 'Cerro de la campana']
#    [0.23570226039551578, 'terre']
#    [0.18257418583505536, 'Derrire']
#    [0.13608276348795434, 'del Milagro']
#    [0.1290994448735805, 'Sierra Madre']
#    [0.09622504486493766, 'hacienda del Milagro']
#    [0.06454972243679025, 'calle del Rosario,- rue du Rosaire']
# Montagne
#    [0.6123724356957945, 'Monta-']
#    [0.3086066999241839, "d'Espagne"]
#    [0.15430334996209194, 'Espagnols']
#    [0.10910894511799618, 'Votre Seigneurie']
# Leperos
#    [1.0, 'Leperos']
#    [0.316227766016838, 'epee']
#    [0.14142135623730945, 'calle del Rosario,- rue du Rosaire']
# Gambusinos
#    [1.0, 'Gambusinos']
#    [0.9354143466934853, 'Gambusino']
#    [0.6666666666666666, 'Gambusinos demi-sang']
#    [0.17677669529663687, 'Jusice']
#    [0.158113883008419, 'inouies']
# Rateros
#    [0.3999999999999999, 'Leperos']
#    [0.2581988897471611, 'terre']
#    [0.19999999999999996, 'Jupiter']
#    [0.14142135623730945, 'calle del Rosario,- rue du Rosaire']
# calle del Rosario
#    [0.7756717518813397, 'calle del Rosario,- rue du Rosaire']
#    [0.2927700218845599, 'le desert']
#    [0.2927700218845599, 'Le desert']
#    [0.22360679774997894, 'golfe de Cali-']
#    [0.18257418583505536, 'hacienda del Milagro']
#    [0.17213259316477403, 'del Milagro']
#    [0.13801311186847087, 'Etats de Durango']
#    [0.1290994448735805, 'Arispe']
#    [0.11547005383792519, 'Leperos']
#    [0.11547005383792519, 'Allonsl']
# rue du Rosaire
#    [0.7302967433402215, 'calle del Rosario,- rue du Rosaire']
#    [0.15430334996209194, 'Etats de Durango']
#    [0.1290994448735805, 'dela du Mississipi']
#    [0.1290994448735805, 'Leperos']
#    [0.1290994448735805, 'Derrire']
#    [0.10910894511799618, 'le desert']
#    [0.10910894511799618, 'Le desert']
#    [0.10206207261596578, 'LA PRAIRIE']
#    [0.09128709291752768, "Tete d'Aigle"]
#    [0.08333333333333337, 'golfe de Cali-']
# Mexique
#    [1.0, 'Mexique']
#    [0.3651483716701107, 'Amerique']
#    [0.3380617018914066, 'Pacifique']
#    [0.316227766016838, "l'Amerique"]
#    [0.18257418583505536, 'Azteques']
# Cerro de la campana
#    [1.0, 'Cerro de la campana']
#    [0.21004201260420152, 'golfe de Cali-']
#    [0.14002800840280094, 'terre']
#    [0.12964074471043285, 'Etats de Durango']
#    [0.10846522890932808, 'Derrire']
#    [0.09901475429766748, 'anatheme']
#    [0.09901475429766748, 'Canadien']
#    [0.0916698497028211, 'le desert']
#    [0.0916698497028211, 'Le desert']
#    [0.0916698497028211, 'La metise']
# Lassez
#    [1.0, 'Lassez']
#    [0.14433756729740643, 'LEs CHAsSSBURs']
# Mexicains
#    [0.5345224838248488, 'Americains']
#    [0.40089186286863654, 'Americaine']
#    [0.3779644730092271, 'Americaines']
#    [0.3380617018914067, 'Mexique']
#    [0.15430334996209194, 'Francais']
# d'Espagne
#    [1.0, "d'Espagne"]
#    [0.5714285714285714, 'Espagnols']
#    [0.10101525445522108, 'Votre Seigneurie']
# II
# hacienda del Milagro
#    [1.0, 'hacienda del Milagro']
#    [0.7071067811865476, 'del Milagro']
#    [0.158113883008419, 'dela du Mississipi']
#    [0.11785113019775795, 'Indien']
#    [0.11180339887498947, 'calle del Rosario,- rue du Rosaire']
#    [0.10540925533894596, 'Indiens']
#    [0.09622504486493766, 'Rio Gila']
#    [0.09622504486493766, 'Lendroit']
#    [0.09622504486493766, 'Canadien']
#    [0.08908708063747484, 'le desert']
# Pérou
# Cordoue
#    [1.0, 'Cordoue']
#    [0.2981423969999719, 'Cordilleres']
# Panama
#    [0.24253562503633297, 'Cerro de la campana']
#    [0.20412414523193145, 'anatheme']
#    [0.20412414523193145, 'Canadien']
#    [0.17677669529663687, 'Canadienne']
# jardin des Oliviers
#    [0.1833396994056422, 'le desert']
#    [0.1833396994056422, 'Le desert']
#    [0.08084520834544429, 'Cordilleres']
#    [0.07669649888473706, 'Sierra Madre']
#    [0.07001400420140047, 'golfe de Cali-']
#    [0.07001400420140047, 'LEs CHAsSSBURs']
#    [0.06482037235521643, 'Etats de Durango']
#    [0.05882352941176472, 'Cerro de la campana']
#    [0.05716619504750298, 'hacienda del Milagro']
#    [0.05716619504750298, 'Gambusinos demi-sang']
# Abandonnera
#    [1.0, 'Abandonnera']
#    [0.16666666666666663, 'Linnee']
#    [0.11785113019775795, 'Canadienne']
# IV
# Providence
#    [1.0, 'Providence']
# Le soleil
#    [1.0, 'Le soleil']
#    [0.7559289460184545, 'soleil']
#    [0.5345224838248488, 'Leil']
#    [0.15430334996209194, 'eveillee']
#    [0.1428571428571428, 'le desert']
#    [0.1428571428571428, 'Le desert']
#    [0.10101525445522108, 'Votre Seigneurie']
#    [0.05976143046671967, 'calle del Rosario,- rue du Rosaire']
# I
# États-Unis
#    [0.875, 'Etats-Unis']
#    [0.40824829046386313, 'Etats']
#    [0.35355339059327373, 'tat']
#    [0.25, 'Etat']
#    [0.18898223650461365, 'Etats de Durango']
# Mississippi
#    [0.6821910402406465, 'dela du Mississipi']
# maison du Blanc
#    [0.22645540682891918, 'Francais']
#    [0.13867504905630723, 'Sonora']
#    [0.12403473458920844, 'dela du Mississipi']
#    [0.10482848367219177, 'Comancles']
#    [0.10482848367219177, 'Comanches']
#    [0.08770580193070288, 'sion etrange']
#    [0.08770580193070288, 'calle del Rosario,- rue du Rosaire']
#    [0.07412493166611012, 'Etats de Durango']
# Indien
#    [1.0, 'Indien']
#    [0.8944271909999159, 'Indiens']
#    [0.408248290463863, 'Canadien']
#    [0.35355339059327373, 'Canadienne']
#    [0.28867513459481287, 'Dieul']
#    [0.18898223650461365, 'Dieul Dix']
#    [0.11785113019775795, 'hacienda del Milagro']
# Canadienne
#    [1.0, 'Canadienne']
#    [0.8660254037844387, 'Canadien']
#    [0.35355339059327373, 'Indien']
#    [0.316227766016838, 'Indiens']
#    [0.20412414523193156, 'Dieul']
#    [0.17677669529663687, 'Linnee']
#    [0.14433756729740643, 'anatheme']
#    [0.13363062095621214, 'Dieul Dix']
#    [0.11785113019775795, 'Abandonnera']
#    [0.08574929257125441, 'Cerro de la campana']
# Arkansas
#    [1.0, 'Arkansas']
#    [0.5477225575051661, 'Aransas']
# rivière Rouge
#    [0.09534625892455928, 'calle del Rosario,- rue du Rosaire']
#    [0.080582296402538, 'Votre Seigneurie']
# Delawares
#    [0.2672612419124244, 'pres']
#    [0.16903085094570325, 'dela du Mississipi']
#    [0.13363062095621214, 'Guadeloupe']
#    [0.12598815766974236, 'del Milagro']
#    [0.12598815766974236, 'Cordilleres']
#    [0.08908708063747484, 'hacienda del Milagro']
#    [0.05976143046671967, 'calle del Rosario,- rue du Rosaire']
# Américains
#    [0.625, 'Americains']
#    [0.5, 'Americaine']
#    [0.4714045207910317, 'Americaines']
#    [0.17677669529663687, 'Cvrics']
#    [0.14433756729740643, 'Francais']
# Pieds-Noirs
# Assiniboins
#    [0.1924500897298752, 'nible']
#    [0.16666666666666663, 'Lassez']
#    [0.16666666666666663, 'Cibolo']
#    [0.14907119849998596, 'dela du Mississipi']
#    [0.12598815766974236, 'Gambusino']
#    [0.11785113019775795, 'Gambusinos']
#    [0.11785113019775795, 'Americains']
#    [0.09622504486493766, 'LEs CHAsSSBURs']
#    [0.0785674201318386, 'Gambusinos demi-sang']
# Lune
#    [1.0, 'Lune']
#    [0.6324555320336759, 'forlune']
# Blanc
#    [0.23570226039551578, 'Francais']
#    [0.21821789023599236, 'Comancles']
#    [0.21821789023599236, 'Comanches']
# Mocksens
#    [0.18257418583505536, 'Indiens']
# Cœur
# Ouest
#    [0.408248290463863, 'Cest']
#    [0.2581988897471611, 'Cordoue']
#    [0.2357022603955159, 'Azteques']
# du Nord
#    [0.22360679774997894, 'Sonora']
#    [0.19999999999999996, 'Cordoue']
#    [0.16903085094570325, 'Ignorante']
#    [0.14907119849998596, 'Cordilleres']
#    [0.09999999999999998, 'dela du Mississipi']
#    [0.07071067811865472, 'calle del Rosario,- rue du Rosaire']
# Puissance
#    [0.16903085094570325, 'dela du Mississipi']
#    [0.15430334996209183, 'Francais']
#    [0.1428571428571428, 'Comancles']
#    [0.1428571428571428, 'Comanches']
#    [0.13363062095621214, 'Providence']
#    [0.08908708063747484, 'Gambusinos demi-sang']
# Comanches
#    [0.9354143466934853, 'Comanches']
#    [0.5345224838248488, 'Comancles']
#    [0.14433756729740643, 'maneuvre']
#    [0.14433756729740643, 'Francais']
# Blancs
#    [0.20412414523193145, 'Francais']
#    [0.18898223650461365, 'Comancles']
#    [0.18898223650461365, 'Comanches']
# La Tête
#    [0.22360679774997894, 'A tors']
#    [0.16903085094570325, 'La metise']
#    [0.158113883008419, 'LA PRAIRIE']
#    [0.10846522890932808, 'Cerro de la campana']
#    [0.09999999999999998, 'dela du Mississipi']
# Aigle
#    [1.0, 'Aigle']
#    [0.5477225575051661, "Tete d'Aigle"]
# Canadien
#    [1.0, 'Canadien']
#    [0.8660254037844387, 'Canadienne']
#    [0.408248290463863, 'Indien']
#    [0.3651483716701107, 'Indiens']
#    [0.2357022603955159, 'Dieul']
#    [0.16666666666666663, 'anatheme']
#    [0.15430334996209194, 'Dieul Dix']
#    [0.09901475429766748, 'Cerro de la campana']
#    [0.09622504486493766, 'hacienda del Milagro']
# Belhumeur
#    [1.0, 'Belhumeur']
#    [0.5916079783099616, 'Parbleul dit Belhumeur']
#    [0.3779644730092273, 'meurtI']
#    [0.2672612419124244, 'Ceur']
#    [0.21821789023599236, 'Caeur']
#    [0.18898223650461365, 'Europe']
#    [0.15430334996209194, 'Malheurl']
#    [0.13363062095621214, 'Ceur Loyal']
#    [0.12598815766974236, 'Caeur Loyal']
#    [0.10101525445522108, 'Votre Seigneurie']
# Tête
# III
# Vert-de-gris
#    [0.21081851067789192, 'decouverte7']
#    [0.158113883008419, 'Arispe']
#    [0.11952286093343933, 'le desert']
#    [0.11952286093343933, 'Le desert']
# Peaux
# Rouges
# Europe
#    [1.0, 'Europe']
#    [0.35355339059327373, 'Ceur']
#    [0.28867513459481287, 'Caeur']
#    [0.25, 'meurtI']
#    [0.20412414523193156, 'Malheurl']
#    [0.18898223650461365, 'Belhumeur']
#    [0.17677669529663687, 'Ceur Loyal']
#    [0.16666666666666663, 'Caeur Loyal']
#    [0.13363062095621214, 'Votre Seigneurie']
#    [0.11180339887498947, 'Parbleul dit Belhumeur']
# Châteaux Blancs
#    [0.11322770341445954, 'Francais']
#    [0.10482848367219177, 'Comancles']
#    [0.10482848367219177, 'Comanches']
# Vert-de-gris
#    [0.20100756305184242, 'decouverte7']
#    [0.15075567228888187, 'Arispe']
#    [0.11396057645963797, 'le desert']
#    [0.11396057645963797, 'Le desert']
# Jupiter
#    [1.0, 'Jupiter']
#    [0.2581988897471611, 'terre']
# Américaines
#    [0.6666666666666666, 'Americaines']
#    [0.5892556509887896, 'Americaine']
#    [0.4714045207910317, 'Americains']
#    [0.16666666666666663, 'Cvrics']
#    [0.13608276348795434, 'Francais']
# Ignorante
#    [1.0, 'Ignorante']
#    [0.3779644730092273, 'Sonora']
#    [0.16903085094570325, 'Durango']
#    [0.16903085094570325, 'Avantde']
#    [0.16903085094570325, 'Aransas']
#    [0.15430334996209194, 'etranger']
#    [0.15430334996209194, 'Francais']
#    [0.1428571428571428, 'Espagnols']
#    [0.11952286093343933, 'sion etrange']
#    [0.10101525445522108, 'Votre Seigneurie']
# Guadeloupe
#    [1.0, 'Guadeloupe']
#    [0.2357022603955159, 'Guadalazara']
#    [0.158113883008419, 'Guaymas']
#    [0.11785113019775795, 'del Milagro']
#    [0.08333333333333337, 'hacienda del Milagro']
#    [0.0790569415042095, 'dela du Mississipi']
#    [0.05590169943749479, 'calle del Rosario,- rue du Rosaire']
# Linnée
#    [0.5, 'Linnee']
# V
# Loyal
#    [0.6546536707079772, 'CurLoyal-']
#    [0.6123724356957946, 'Ceur Loyal']
#    [0.5773502691896257, 'Caeur Loyal']
# lointain
#    [0.18898223650461365, 'Monta-']
#    [0.13363062095621214, 'Americains']
#    [0.13363062095621214, 'Americaine']
#    [0.12598815766974236, 'Americaines']

# %%
print("test sur le temps de calcul")

for NB in [10, 50, 100, 500]:
  start = time.time()
  liste_filter = list(set(liste_aimard_kraken))[:NB]
  NBtyp = len(liste_filter)
  print(f"Calcul pour  {NBtyp} entités uniques")
  
  out = tc.get_similar_in_list(liste_filter)
  end = time.time()
  print("Results computed in %f seconds : \n"%(end-start))
# Out:
# test sur le temps de calcul
# Calcul pour  10 entités uniques
# Results computed in 0.020154 seconds :
#
# Calcul pour  50 entités uniques
# Results computed in 0.162498 seconds :
#
# Calcul pour  100 entités uniques
# Results computed in 0.629586 seconds :
#
# Calcul pour  470 entités uniques
# Results computed in 14.486719 seconds :
